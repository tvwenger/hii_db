# %% [markdown]
# # HII Region Database Generator
# Generates a database containing a subset of the information about Galactic HII regions in the
# [WISE Catalog of Galactic HII Regions](http://astro.phys.wvu.edu/wise/)
# ([paper](https://ui.adsabs.harvard.edu/abs/2014ApJS..212....1A/abstract)) along with additional
# information related to recent radio recombination line surveys. The database structure is described
# in `schema.txt`.
#
# First, download the data files from THIS LINK.
#
# Then, if necessary, update the WISE Catalog database by running the notebook `generate_wise_catalog.ipynb`.
#
# Copyright(C) 2025 by<br>
# Trey V. Wenger; tvwenger@gmail.com<br>
# L. D. Anderson; <br>
# This code is licensed under MIT license (see LICENSE for details)

# %%
# Import packages
import os
from hii_db import generate
from hii_db import add_parallax
from hii_db import add_distances
from hii_db import utils

import importlib
importlib.reload(utils)
# Out:
# <module 'hii_db.utils' from '/home/twenger/science/python/hii_db/hii_db/utils.py'>

# %%
# Set filepath for data directory
data_dir = "/media/drive1/hii-db-data/"

# WISE Catalog CSV file
wise_master_version = 3.0
wise_csv_file = os.path.join(data_dir, "wise", f"WISE_HII_V{wise_master_version}.csv")

if not os.path.exists(wise_csv_file):
    raise FileNotFoundError(wise_csv_file)
print(f"Using WISE Catalog CSV: {wise_csv_file}")

# Output database file
db_version = "v2025_07_29"
db_file = os.path.join(data_dir, "db", f"hii_{db_version}.db")
wise_db_file = os.path.join(data_dir, "db", f"hii_{db_version}_wise.db")
print(f"Database will be overwritten: {db_file} and {wise_db_file}")
# Out:
# Using WISE Catalog CSV: /media/drive1/hii-db-data/wise/WISE_HII_V3.0.csv
# Database will be overwritten: /media/drive1/hii-db-data/db/hii_v2025_07_29.db and /media/drive1/hii-db-data/db/hii_v2025_07_29_wise.db

# %% [markdown]
# # Build WISE Catalog-only Database

# %%
generate.main(wise_db_file, wise_csv_file, wise_only=True, data_dir=data_dir)
# Out:
# Resetting database...
# Done!
#
# Generating WISE Catalog table...
# 8589
# 8589
# Done!
#
# Generating Groups table...
# Group G000.510-00.051 different VLSR nan vs nan
# Group WB43 different VLSR nan vs nan
# Group WB43 different VLSR nan vs nan
# Done!
#
# Matching Catalog to Groups...
# Done!
#
# Adding WISE Detections...
# PROBLEM WITH G000.320-00.215 COMPONENTS
# [9.6]
# [0.5]
# [27.2]
# [0.7]
# [nan]
# [nan]
# ================================
# PROBLEM WITH G012.685+00.008 COMPONENTS
# [ 34.1 109. ]
# [0.7 0.9]
# [30.4  nan]
# [1.7 nan]
# [0.18105     nan]
# [0.03995     nan]
# ================================
# PROBLEM WITH G014.221-00.545 COMPONENTS
# [19.7 54.5]
# [0.8 1.7]
# [28.4  nan]
# [ 2. nan]
# [0.11475     nan]
# [0.0289    nan]
# ================================
# PROBLEM WITH G023.195-00.001 COMPONENTS
# [90.7 22.4]
# [0.7 1.7]
# [28.3  nan]
# [1.6 nan]
# [0.12155     nan]
# [0.02635     nan]
# ================================
# PROBLEM WITH G055.855-03.803 COMPONENTS
# [27.6]
# [0.2]
# [24.2]
# [0.3]
# [nan]
# [nan]
# ================================
# PROBLEM WITH G107.209-01.334 COMPONENTS
# [-36.]
# [0.4]
# [26.9]
# [0.7]
# [nan]
# [nan]
# ================================
# PROBLEM WITH G108.503+06.356 COMPONENTS
# [-10.3]
# [0.3]
# [23.9]
# [0.6]
# [nan]
# [nan]
# ================================
# PROBLEM WITH G114.605-00.801 COMPONENTS
# [-47.9]
# [0.8]
# [26.1]
# [1.5]
# [nan]
# [nan]
# ================================
# PROBLEM WITH G114.626+00.219 COMPONENTS
# [-32.8]
# [0.3]
# [29.]
# [0.6]
# [nan]
# [nan]
# ================================
# PROBLEM WITH G115.885-01.707 COMPONENTS
# [-43.8]
# [0.4]
# [26.9]
# [0.8]
# [nan]
# [nan]
# ================================
# PROBLEM WITH G118.621-01.329 COMPONENTS
# [-42.6]
# [0.5]
# [27.]
# [0.9]
# [nan]
# [nan]
# ================================
# PROBLEM WITH G134.970+00.699 COMPONENTS
# [-43.9]
# [0.3]
# [33.9]
# [0.4]
# [nan]
# [nan]
# ================================
# PROBLEM WITH G136.084+02.087 COMPONENTS
# [-44.7]
# [0.5]
# [31.3]
# [0.9]
# [nan]
# [nan]
# ================================
# PROBLEM WITH G136.119+02.118 COMPONENTS
# [-49.6]
# [0.3]
# [28.9]
# [0.6]
# [nan]
# [nan]
# ================================
# PROBLEM WITH G143.555-01.542 COMPONENTS
# [-36.7]
# [0.6]
# [35.9]
# [1.4]
# [nan]
# [nan]
# ================================
# PROBLEM WITH G147.984-00.335 COMPONENTS
# [-16.8]
# [0.3]
# [32.8]
# [0.6]
# [nan]
# [nan]
# ================================
# PROBLEM WITH G150.982-00.471 COMPONENTS
# [-23.9]
# [1.6]
# [33.8]
# [2.4]
# [nan]
# [nan]
# ================================
# PROBLEM WITH G152.687+02.889 COMPONENTS
# [-16.8]
# [0.6]
# [44.8]
# [1.3]
# [nan]
# [nan]
# ================================
# PROBLEM WITH G168.171+03.054 COMPONENTS
# [-23.1]
# [0.3]
# [35.1]
# [0.5]
# [nan]
# [nan]
# ================================
# PROBLEM WITH G168.750+00.873 COMPONENTS
# [-26.3]
# [0.4]
# [40.1]
# [0.6]
# [nan]
# [nan]
# ================================
# PROBLEM WITH G172.080-02.258 COMPONENTS
# [4.4]
# [0.1]
# [40.9]
# [0.2]
# [nan]
# [nan]
# ================================
# PROBLEM WITH G191.916+00.837 COMPONENTS
# [9.6]
# [2.]
# [39.1]
# [3.]
# [nan]
# [nan]
# ================================
# PROBLEM WITH G192.720+00.038 COMPONENTS
# [7.9]
# [1.1]
# [45.4]
# [1.8]
# [nan]
# [nan]
# ================================
# PROBLEM WITH G195.335-12.122 COMPONENTS
# [5.6]
# [0.4]
# [37.4]
# [0.6]
# [nan]
# [nan]
# ================================
# PROBLEM WITH G206.466-16.349 COMPONENTS
# [13.8]
# [0.2]
# [34.4]
# [0.3]
# [nan]
# [nan]
# ================================
# PROBLEM WITH G210.788-02.545 COMPONENTS
# [-21.   36.8]
# [0.4 0.3]
# [24.1 44.5]
# [0.6 0.6]
# [nan nan]
# [nan nan]
# ================================
# PROBLEM WITH G211.245-00.424 COMPONENTS
# [8.1]
# [0.4]
# [37.3]
# [0.6]
# [nan]
# [nan]
# ================================
# PROBLEM WITH G217.297-01.393 COMPONENTS
# [-21.   35.7]
# [1.5 1.4]
# [27.2 50.7]
# [2.1 2.4]
# [nan nan]
# [nan nan]
# ================================
# PROBLEM WITH G217.440+00.331 COMPONENTS
# [-18.5  23.6]
# [1.1 1.3]
# [20.2 36.3]
# [1.6 2.2]
# [nan nan]
# [nan nan]
# ================================
# PROBLEM WITH G217.629-00.178 COMPONENTS
# [16.6]
# [1.9]
# [61.2]
# [3.2]
# [nan]
# [nan]
# ================================
# PROBLEM WITH G218.131-00.397 COMPONENTS
# [16.3]
# [0.6]
# [47.1]
# [0.9]
# [nan]
# [nan]
# ================================
# PROBLEM WITH G218.808-04.558 COMPONENTS
# [-13.5  51.1]
# [1.2 0.8]
# [41.1 48. ]
# [1.8 1.4]
# [nan nan]
# [nan nan]
# ================================
# PROBLEM WITH G224.149-02.913 COMPONENTS
# [8.5]
# [0.7]
# [25.]
# [1.4]
# [nan]
# [nan]
# ================================
# PROBLEM WITH G224.405-02.740 COMPONENTS
# [13.9]
# [1.1]
# [25.4]
# [2.3]
# [nan]
# [nan]
# ================================
# PROBLEM WITH G231.142+01.503 COMPONENTS
# [45.7]
# [0.7]
# [16.6]
# [1.6]
# [nan]
# [nan]
# ================================
# PROBLEM WITH G232.594+00.851 COMPONENTS
# [-15.5  17.6]
# [1.2 0.3]
# [19.9 32.1]
# [1.7 0.5]
# [nan nan]
# [nan nan]
# ================================
# PROBLEM WITH G234.227-00.309 COMPONENTS
# [-10.3  42.8]
# [2.1 0.6]
# [32.8 35.5]
# [3.3 1. ]
# [nan nan]
# [nan nan]
# ================================
# PROBLEM WITH G352.587+02.104 COMPONENTS
# [0.6]
# [0.4]
# [28.5]
# [0.5]
# [nan]
# [nan]
# ================================
# PROBLEM WITH G355.924+01.634 COMPONENTS
# [6.6]
# [1.8]
# [22.7]
# [0.2]
# [nan]
# [nan]
# ================================
# PROBLEM WITH G358.464-01.897 COMPONENTS
# [-1.3]
# [0.6]
# [25.5]
# [0.3]
# [nan]
# [nan]
# ================================
# Done!
#
# Matching WISE Detections to WISE Catalog...
# Done!

# %% [markdown]
# # Add Parallax Data to WISE-only Database

# %%
reid19_datafile = os.path.join(data_dir, "masers", "reid2019_merge.txt")
reid19_reffile = os.path.join(data_dir, "masers", "reid2019_refs.txt")

add_parallax.main(wise_db_file, datafile=reid19_datafile, reffile=reid19_reffile)
# Out:
# Resetting Parallax and CatalogParallax tables...
# Done.
#
# Adding Reid+2019 Parallax sources...
# Populating Parallax table...
# Done!
#
# Matching Parallax sources to WISE Catalog...
# Matching WISE G000.314-00.194 to parallax G000.31-00.20 based on WISE size
# Matching WISE G000.314-00.205 to parallax G000.31-00.20 based on WISE size
# Matching WISE G000.320-00.215 to parallax G000.31-00.20 based on WISE size
# Matching WISE G000.382+00.017 to parallax G000.37+00.03 based on separation (85.6 arcsec)
# Matching WISE G000.657-00.041 to parallax G000.67-00.03 based on separation (65.5 arcsec)
# Matching WISE G000.660-00.052 to parallax G000.67-00.03 based on separation (86.8 arcsec)
# Matching WISE G000.666-00.036 to parallax G000.67-00.03 based on separation (28.4 arcsec)
# Matching WISE G000.666-00.051 to parallax G000.67-00.03 based on separation (72.9 arcsec)
# Matching WISE G000.670-00.043 to parallax G000.67-00.03 based on separation (40.2 arcsec)
# Matching WISE G000.670-00.035 to parallax G000.67-00.03 based on WISE size
# Matching WISE G000.676-00.043 to parallax G000.67-00.03 based on separation (42.5 arcsec)
# Matching WISE G000.681-00.035 to parallax G000.67-00.03 based on separation (35.9 arcsec)
# Matching WISE G000.692-00.047 to parallax G000.67-00.03 based on separation (90.0 arcsec)
# Matching WISE G001.005-00.236 to parallax G001.00-00.23 based on WISE size
# Matching WISE G001.011-00.217 to parallax G001.00-00.23 based on separation (75.9 arcsec)
# Matching WISE G001.218-00.034 to parallax G001.14-00.12 based on WISE size
# Matching WISE G002.688+00.046 to parallax G002.70+00.04 based on separation (58.9 arcsec)
# Matching WISE G002.695+00.024 to parallax G002.70+00.04 based on separation (63.9 arcsec)
# Matching WISE G002.696+00.033 to parallax G002.70+00.04 based on WISE size
# Matching WISE G005.883-00.399 to parallax G005.88-00.39 based on WISE size
# Matching WISE G005.885-00.393 to parallax G005.88-00.39 based on WISE size
# Matching WISE G005.887-00.443 to parallax G005.88-00.39 based on WISE size
# Matching WISE G006.795-00.257 to parallax G006.79-00.25 based on WISE size
# Matching WISE G007.470+00.059 to parallax G007.47+00.05 based on WISE size
# Matching WISE G009.212-00.206 to parallax G009.21-00.20 based on WISE size
# Matching WISE G009.598+00.199 to parallax G009.62+00.19 based on separation (82.2 arcsec)
# Matching WISE G009.612+00.205 to parallax G009.62+00.19 based on separation (47.5 arcsec)
# Matching WISE G009.613+00.200 to parallax G009.62+00.19 based on WISE size
# Matching WISE G010.308-00.150 to parallax G010.32-00.15 based on WISE size
# Matching WISE G010.453+00.029 to parallax G010.47+00.02 based on separation (70.0 arcsec)
# Matching WISE G010.462+00.034 to parallax G010.47+00.02 based on separation (44.4 arcsec)
# Matching WISE G010.464+00.029 to parallax G010.47+00.02 based on separation (30.3 arcsec)
# Matching WISE G010.469+00.023 to parallax G010.47+00.02 based on separation (17.3 arcsec)
# Matching WISE G010.472+00.026 to parallax G010.47+00.02 based on WISE size
# Matching WISE G010.472+00.017 to parallax G010.47+00.02 based on separation (34.5 arcsec)
# Matching WISE G010.475+00.031 to parallax G010.47+00.02 based on separation (19.9 arcsec)
# Matching WISE G010.486+00.042 to parallax G010.47+00.02 based on separation (74.5 arcsec)
# Matching WISE G010.607-00.345 to parallax G010.62-00.33 based on separation (88.1 arcsec)
# Matching WISE G010.611-00.375 to parallax G010.62-00.38 based on separation (51.9 arcsec)
# Matching WISE G010.617-00.336 to parallax G010.62-00.33 based on separation (41.7 arcsec)
# Matching WISE G010.617-00.405 to parallax G010.62-00.38 based on separation (80.4 arcsec)
# Matching WISE G010.618-00.383 to parallax G010.62-00.38 based on separation (18.5 arcsec)
# Matching WISE G010.621-00.318 to parallax G010.62-00.33 based on separation (61.2 arcsec)
# Matching WISE G010.621-00.380 to parallax G010.62-00.38 based on separation (14.3 arcsec)
# Matching WISE G010.623-00.385 to parallax G010.62-00.38 based on WISE size
# Matching WISE G010.626-00.373 to parallax G010.62-00.38 based on separation (38.5 arcsec)
# Matching WISE G010.629-00.342 to parallax G010.62-00.33 based on separation (32.4 arcsec)
# Matching WISE G010.629-00.339 to parallax G010.62-00.33 based on WISE size
# Matching WISE G010.631-00.388 to parallax G010.62-00.38 based on separation (32.2 arcsec)
# Matching WISE G011.935-00.613 to parallax G011.91-00.61 based on WISE size
# Matching WISE G012.025-00.032 to parallax G012.02-00.03 based on WISE size
# Matching WISE G012.026-00.020 to parallax G012.02-00.03 based on separation (44.2 arcsec)
# Matching WISE G012.683-00.185 to parallax G012.68-00.18 based on WISE size
# Matching WISE G012.794-00.199 to parallax G012.81-00.19 based on separation (69.6 arcsec)
# Matching WISE G012.794-00.188 to parallax G012.81-00.19 based on separation (76.9 arcsec)
# Matching WISE G012.795-00.192 to parallax G012.81-00.19 based on separation (68.3 arcsec)
# Matching WISE G012.804-00.207 to parallax G012.81-00.19 based on separation (47.2 arcsec)
# Matching WISE G012.805-00.196 to parallax G012.81-00.19 based on separation (30.0 arcsec)
# Matching WISE G012.813-00.200 to parallax G012.81-00.19 based on WISE size
# Matching WISE G012.878+00.495 to parallax G012.88+00.48 based on separation (43.8 arcsec)
# Matching WISE G012.881+00.480 to parallax G012.88+00.48 based on separation (39.8 arcsec)
# Matching WISE G012.884-00.237 to parallax G012.90-00.24 based on WISE size
# Matching WISE G012.886+00.473 to parallax G012.88+00.48 based on separation (56.7 arcsec)
# Matching WISE G012.888+00.489 to parallax G012.88+00.48 based on WISE size
# Matching WISE G012.888+00.508 to parallax G012.88+00.48 based on separation (69.4 arcsec)
# Matching WISE G012.890+00.494 to parallax G012.88+00.48 based on WISE size
# Matching WISE G012.907-00.277 to parallax G012.90-00.26 based on WISE size
# Matching WISE G013.725-00.024 to parallax G013.71-00.08 based on WISE size
# Matching WISE G013.880+00.285 to parallax G013.87+00.28 based on WISE size
# Matching WISE G014.331-00.640 to parallax G014.33-00.64 based on WISE size
# Matching WISE G014.351-00.642 to parallax G014.33-00.64 based on separation (72.5 arcsec)
# Matching WISE G014.634-00.594 to parallax G014.63-00.57 based on separation (64.7 arcsec)
# Matching WISE G014.640-00.605 to parallax G014.63-00.57 based on WISE size
# Matching WISE G015.097-00.729 to parallax G015.03-00.67 based on WISE size
# Matching WISE G015.655-00.480 to parallax G015.66-00.49 based on separation (79.5 arcsec)
# Matching WISE G016.577-00.038 to parallax G016.58-00.05 based on separation (54.0 arcsec)
# Matching WISE G016.580-00.045 to parallax G016.58-00.05 based on separation (27.2 arcsec)
# Matching WISE G016.582-00.051 to parallax G016.58-00.05 based on WISE size
# Matching WISE G016.583-00.053 to parallax G016.58-00.05 based on WISE size
# Matching WISE G016.584-00.036 to parallax G016.58-00.05 based on separation (53.7 arcsec)
# Matching WISE G017.638+00.157 to parallax G017.63+00.15 based on WISE size
# Matching WISE G017.652+00.150 to parallax G017.63+00.15 based on separation (55.5 arcsec)
# Matching WISE G018.426+01.922 to parallax G018.34+01.76 based on WISE size
# Matching WISE G018.725-00.046 to parallax G018.87+00.05 based on WISE size
# Matching WISE G018.884+00.049 to parallax G018.87+00.05 based on WISE size
# Matching WISE G018.978+00.030 to parallax G019.00-00.02 based on WISE size
# Matching WISE G019.356-00.035 to parallax G019.36-00.03 based on separation (35.0 arcsec)
# Matching WISE G019.360-00.014 to parallax G019.36-00.03 based on separation (61.7 arcsec)
# Matching WISE G019.365-00.030 to parallax G019.36-00.03 based on WISE size
# Matching WISE G019.466+00.168 to parallax G019.49+00.11 based on WISE size
# Matching WISE G019.489+00.135 to parallax G019.49+00.11 based on separation (75.1 arcsec)
# Matching WISE G022.357+00.064 to parallax G022.35+00.06 based on WISE size
# Matching WISE G022.478-00.015 to parallax G022.35+00.06 based on WISE size
# Matching WISE G022.996-00.410 to parallax G023.00-00.41 based on separation (47.2 arcsec)
# Matching WISE G023.011-00.421 to parallax G023.00-00.41 based on WISE size
# Matching WISE G023.015-00.395 to parallax G023.00-00.41 based on separation (61.1 arcsec)
# Matching WISE G023.041-00.399 to parallax G023.00-00.41 based on WISE size
# Matching WISE G023.240-00.240 to parallax G023.25-00.24 based on WISE size
# Matching WISE G023.253-00.240 to parallax G023.25-00.24 based on WISE size
# Matching WISE G023.271-00.256 to parallax G023.25-00.24 based on separation (75.6 arcsec)
# Matching WISE G023.439-00.187 to parallax G023.43-00.18 based on WISE size
# Matching WISE G023.455-00.201 to parallax G023.43-00.18 based on separation (87.0 arcsec)
# Matching WISE G023.458-00.179 to parallax G023.43-00.18 based on separation (66.3 arcsec)
# Matching WISE G023.657-00.128 to parallax G023.65-00.12 based on WISE size
# Matching WISE G023.689-00.205 to parallax G023.70-00.19 based on separation (65.2 arcsec)
# Matching WISE G023.703-00.197 to parallax G023.70-00.19 based on WISE size
# Matching WISE G023.708-00.205 to parallax G023.70-00.19 based on WISE size
# Matching WISE G024.789+00.084 to parallax G024.78+00.08 based on WISE size
# Matching WISE G024.793+00.096 to parallax G024.78+00.08 based on separation (48.4 arcsec)
# Matching WISE G024.844+00.093 to parallax G024.85+00.08 based on WISE size
# Matching WISE G024.919+00.294 to parallax G024.85+00.08 based on WISE size
# Matching WISE G025.700+00.028 to parallax G025.70+00.04 based on WISE size
# Matching WISE G025.715+00.048 to parallax G025.70+00.04 based on WISE size
# Matching WISE G025.724+00.058 to parallax G025.70+00.04 based on separation (76.1 arcsec)
# Matching WISE G025.867+00.118 to parallax G025.70+00.04 based on WISE size
# Matching WISE G027.366-00.164 to parallax G027.36-00.16 based on WISE size
# Matching WISE G028.145+00.001 to parallax G028.14-00.00 based on WISE size
# Matching WISE G028.146-00.005 to parallax G028.14-00.00 based on WISE size
# Matching WISE G028.305-00.390 to parallax G028.30-00.38 based on WISE size
# Matching WISE G028.394+00.076 to parallax G028.39+00.08 based on WISE size
# Matching WISE G028.823-00.226 to parallax G028.83-00.25 based on WISE size
# Matching WISE G028.839-00.251 to parallax G028.83-00.25 based on WISE size
# Matching WISE G028.861+00.065 to parallax G028.86+00.06 based on WISE size
# Matching WISE G029.814-00.069 to parallax G029.86-00.04 based on WISE size
# Matching WISE G029.862-00.059 to parallax G029.86-00.04 based on separation (51.6 arcsec)
# Matching WISE G029.956-00.020 to parallax G029.95-00.01 based on WISE size
# Matching WISE G030.196-00.171 to parallax G030.19-00.16 based on WISE size
# Matching WISE G030.212-00.157 to parallax G030.19-00.16 based on separation (70.9 arcsec)
# Matching WISE G030.219-00.179 to parallax G030.22-00.18 based on WISE size
# Matching WISE G030.248-00.102 to parallax G030.22-00.18 based on WISE size
# Matching WISE G030.338-00.252 to parallax G030.41-00.23 based on WISE size
# Matching WISE G030.410-00.228 to parallax G030.41-00.23 based on separation (34.8 arcsec)
# Matching WISE G030.688-00.075 to parallax G030.70-00.06 based on separation (55.1 arcsec)
# Matching WISE G030.691-00.049 to parallax G030.70-00.06 based on separation (82.2 arcsec)
# Matching WISE G030.720-00.083 to parallax G030.70-00.06 based on separation (81.4 arcsec)
# Matching WISE G030.758-00.047 to parallax G030.74-00.04 based on WISE size
# Matching WISE G030.793+00.196 to parallax G030.78+00.20 based on separation (30.9 arcsec)
# Matching WISE G030.796+00.183 to parallax G030.78+00.20 based on WISE size
# Matching WISE G030.808+00.216 to parallax G030.78+00.20 based on separation (86.1 arcsec)
# Matching WISE G031.241-00.109 to parallax G031.24-00.11 based on WISE size
# Matching WISE G031.242-00.130 to parallax G031.24-00.11 based on separation (68.8 arcsec)
# Matching WISE G031.244-00.113 to parallax G031.24-00.11 based on WISE size
# Matching WISE G031.269+00.064 to parallax G031.28+00.06 based on separation (41.2 arcsec)
# Matching WISE G031.279+00.061 to parallax G031.28+00.06 based on WISE size
# Matching WISE G031.412+00.309 to parallax G031.41+00.30 based on WISE size
# Matching WISE G031.567+00.078 to parallax G031.58+00.07 based on separation (47.7 arcsec)
# Matching WISE G031.577+00.103 to parallax G031.58+00.07 based on WISE size
# Matching WISE G031.580+00.074 to parallax G031.58+00.07 based on WISE size
# Matching WISE G032.030+00.048 to parallax G032.04+00.05 based on separation (62.8 arcsec)
# Matching WISE G032.058+00.077 to parallax G032.04+00.05 based on separation (80.4 arcsec)
# Matching WISE G032.749-00.065 to parallax G032.74-00.07 based on separation (43.2 arcsec)
# Matching WISE G032.775+00.183 to parallax G032.79+00.19 based on separation (82.5 arcsec)
# Matching WISE G032.793+00.206 to parallax G032.79+00.19 based on separation (57.3 arcsec)
# Matching WISE G032.798+00.186 to parallax G032.79+00.19 based on WISE size
# Matching WISE G032.798+00.193 to parallax G032.79+00.19 based on WISE size
# Matching WISE G032.800+00.190 to parallax G032.79+00.19 based on WISE size
# Matching WISE G033.051-00.078 to parallax G033.09-00.07 based on WISE size
# Matching WISE G033.391-00.012 to parallax G033.39+00.00 based on separation (78.3 arcsec)
# Matching WISE G033.403+00.005 to parallax G033.39+00.00 based on WISE size
# Matching WISE G033.507-00.003 to parallax G033.39+00.00 based on WISE size
# Matching WISE G033.643-00.229 to parallax G033.64-00.22 based on WISE size
# Matching WISE G034.404+00.227 to parallax G034.41+00.23 based on WISE size
# Matching WISE G034.997+00.330 to parallax G035.02+00.34 based on WISE size
# Matching WISE G035.025+00.350 to parallax G035.02+00.34 based on WISE size
# Matching WISE G035.063+00.330 to parallax G035.02+00.34 based on WISE size
# Matching WISE G035.197-00.743 to parallax G035.19-00.74 based on WISE size
# Matching WISE G035.197-01.756 to parallax G035.20-01.73 based on WISE size
# Matching WISE G037.347-00.147 to parallax G037.47-00.10 based on WISE size
# Matching WISE G037.419+01.513 to parallax G037.42+01.51 based on WISE size
# Matching WISE G037.469-00.105 to parallax G037.47-00.10 based on WISE size
# Matching WISE G037.642+01.192 to parallax G037.42+01.51 based on WISE size
# Matching WISE G038.101-00.238 to parallax G038.11-00.22 based on separation (71.3 arcsec)
# Matching WISE G038.121-00.226 to parallax G038.11-00.22 based on WISE size
# Matching WISE G040.154+00.648 to parallax G040.42+00.70 based on WISE size
# Matching WISE G040.282-00.220 to parallax G040.28-00.21 based on WISE size
# Matching WISE G040.285-00.239 to parallax G040.28-00.21 based on separation (70.9 arcsec)
# Matching WISE G040.399+00.683 to parallax G040.42+00.70 based on WISE size
# Matching WISE G040.430+00.697 to parallax G040.42+00.70 based on WISE size
# Matching WISE G040.622-00.138 to parallax G040.62-00.13 based on WISE size
# Matching WISE G041.074-00.162 to parallax G041.15-00.20 based on WISE size
# Matching WISE G041.232-00.203 to parallax G041.22-00.19 based on WISE size
# Matching WISE G042.065+00.244 to parallax G042.03+00.19 based on WISE size
# Matching WISE G043.040-00.445 to parallax G043.03-00.45 based on WISE size
# Matching WISE G043.146+00.013 to parallax G043.16+00.01 based on separation (72.2 arcsec)
# Matching WISE G043.149+00.028 to parallax G043.16+00.01 based on separation (88.5 arcsec)
# Matching WISE G043.151+00.011 to parallax G043.16+00.01 based on separation (53.3 arcsec)
# Matching WISE G043.154+00.006 to parallax G043.16+00.01 based on separation (45.3 arcsec)
# Matching WISE G043.154+00.018 to parallax G043.16+00.01 based on separation (50.0 arcsec)
# Matching WISE G043.162+00.005 to parallax G043.16+00.01 based on separation (23.8 arcsec)
# Matching WISE G043.167-00.005 to parallax G043.16+00.01 based on separation (55.0 arcsec)
# Matching WISE G043.168+00.019 to parallax G043.16+00.01 based on separation (32.0 arcsec)
# Matching WISE G043.170-00.004 to parallax G043.16+00.01 based on WISE size
# Matching WISE G043.173+00.015 to parallax G043.16+00.01 based on separation (29.2 arcsec)
# Matching WISE G043.175+00.025 to parallax G043.16+00.01 based on separation (61.1 arcsec)
# Matching WISE G043.179+00.020 to parallax G043.16+00.01 based on separation (59.5 arcsec)
# Matching WISE G043.183+00.018 to parallax G043.16+00.01 based on separation (67.6 arcsec)
# Matching WISE G043.792-00.122 to parallax G043.79-00.12 based on WISE size
# Matching WISE G043.794-00.129 to parallax G043.79-00.12 based on WISE size
# Matching WISE G043.887-00.800 to parallax G043.89-00.78 based on separation (54.4 arcsec)
# Matching WISE G043.890-00.780 to parallax G043.89-00.78 based on WISE size
# Matching WISE G045.067+00.140 to parallax G045.07+00.13 based on separation (33.2 arcsec)
# Matching WISE G045.070+00.132 to parallax G045.07+00.13 based on WISE size
# Matching WISE G045.453+00.044 to parallax G045.45+00.06 based on WISE size
# Matching WISE G045.466+00.045 to parallax G045.45+00.06 based on separation (65.9 arcsec)
# Matching WISE G045.470+00.133 to parallax G045.49+00.12 based on separation (87.3 arcsec)
# Matching WISE G045.471+00.075 to parallax G045.45+00.06 based on separation (83.4 arcsec)
# Matching WISE G045.475+00.130 to parallax G045.49+00.12 based on WISE size
# Matching WISE G045.484+00.143 to parallax G045.49+00.12 based on separation (72.2 arcsec)
# Matching WISE G045.806-00.353 to parallax G045.80-00.35 based on WISE size
# Matching WISE G048.599+00.044 to parallax G048.60+00.02 based on WISE size
# Matching WISE G048.599+00.017 to parallax G048.60+00.02 based on separation (30.2 arcsec)
# Matching WISE G048.602+00.025 to parallax G048.60+00.02 based on separation (16.4 arcsec)
# Matching WISE G048.604+00.022 to parallax G048.60+00.02 based on WISE size
# Matching WISE G048.605+00.021 to parallax G048.60+00.02 based on WISE size
# Matching WISE G048.606+00.024 to parallax G048.60+00.02 based on WISE size
# Matching WISE G048.609+00.027 to parallax G048.60+00.02 based on separation (18.5 arcsec)
# Matching WISE G048.620+00.028 to parallax G048.60+00.02 based on separation (53.9 arcsec)
# Matching WISE G048.624+00.014 to parallax G048.60+00.02 based on separation (71.3 arcsec)
# Matching WISE G048.627+00.020 to parallax G048.60+00.02 based on separation (77.6 arcsec)
# Matching WISE G048.871-00.383 to parallax G048.99-00.29 based on WISE size
# Matching WISE G049.002-00.303 to parallax G048.99-00.29 based on WISE size
# Matching WISE G049.201-00.365 to parallax G049.19-00.33 based on WISE size
# Matching WISE G049.408+00.332 to parallax G049.41+00.32 based on WISE size
# Matching WISE G049.420+00.320 to parallax G049.41+00.32 based on WISE size
# Matching WISE G049.484-00.391 to parallax G049.48-00.38 based on WISE size
# Matching WISE G049.487-00.353 to parallax G049.48-00.36 based on separation (60.6 arcsec)
# Matching WISE G049.489-00.378 to parallax G049.48-00.36 based on separation (30.6 arcsec)
# Matching WISE G049.491-00.367 to parallax G049.48-00.36 based on WISE size
# Matching WISE G049.494-00.345 to parallax G049.48-00.36 based on separation (89.8 arcsec)
# Matching WISE G049.728+00.129 to parallax G049.41+00.32 based on WISE size
# Matching WISE G052.098+01.042 to parallax G052.10+01.04 based on WISE size
# Matching WISE G054.099-00.068 to parallax G054.10-00.08 based on WISE size
# Matching WISE G058.769+00.648 to parallax G058.77+00.64 based on WISE size
# Matching WISE G059.477-00.186 to parallax G059.47-00.18 based on WISE size
# Matching WISE G059.557-00.186 to parallax G059.47-00.18 based on WISE size
# Matching WISE G059.774+00.081 to parallax G059.78+00.06 based on separation (67.3 arcsec)
# Matching WISE G059.780+00.065 to parallax G059.78+00.06 based on WISE size
# Matching WISE G059.789+00.053 to parallax G059.78+00.06 based on separation (45.0 arcsec)
# Matching WISE G059.829+00.671 to parallax G059.83+00.67 based on WISE size
# Matching WISE G060.575-00.186 to parallax G060.57-00.18 based on WISE size
# Matching WISE G069.539-00.977 to parallax G069.54-00.97 based on WISE size
# Matching WISE G070.099+01.629 to parallax G070.18+01.74 based on WISE size
# Matching WISE G070.196+01.677 to parallax G070.18+01.74 based on WISE size
# Matching WISE G071.312+00.828 to parallax G071.31+00.82 based on WISE size
# Matching WISE G071.519-00.389 to parallax G071.52-00.38 based on WISE size
# Matching WISE G074.342+00.937 to parallax G074.56+00.84 based on WISE size
# Matching WISE G075.295+01.321 to parallax G075.29+01.32 based on WISE size
# Matching WISE G075.768+00.344 to parallax G075.76+00.33 based on WISE size
# Matching WISE G076.361-00.625 to parallax G076.38-00.61 based on separation (72.5 arcsec)
# Matching WISE G076.384-00.621 to parallax G076.38-00.61 based on WISE size
# Matching WISE G078.123+03.631 to parallax G078.12+03.63 based on WISE size
# Matching WISE G078.714+03.115 to parallax G078.12+03.63 based on WISE size
# Matching WISE G078.886+00.709 to parallax G078.88+00.70 based on WISE size
# Matching WISE G079.869+01.180 to parallax G079.87+01.17 based on WISE size
# Matching WISE G080.362+01.212 to parallax G079.87+01.17 based on WISE size
# Matching WISE G080.880+00.410 to parallax G080.86+00.38 based on WISE size
# Matching WISE G081.878+00.778 to parallax G081.87+00.78 based on WISE size
# Matching WISE G081.920+00.138 to parallax G081.75+00.59 based on WISE size
# Matching WISE G090.856+01.691 to parallax G090.92+01.48 based on WISE size
# Matching WISE G090.919+01.493 to parallax G090.92+01.48 based on WISE size
# Matching WISE G090.964+01.552 to parallax G090.92+01.48 based on WISE size
# Matching WISE G092.658+03.054 to parallax G092.67+03.07 based on separation (77.2 arcsec)
# Matching WISE G092.677+03.053 to parallax G092.67+03.07 based on separation (69.3 arcsec)
# Matching WISE G092.680+03.072 to parallax G092.67+03.07 based on WISE size
# Matching WISE G092.920+02.823 to parallax G092.67+03.07 based on WISE size
# Matching WISE G094.890-01.643 to parallax G094.60-01.79 based on WISE size
# Matching WISE G097.515+03.173 to parallax G097.53+03.18 based on WISE size
# Matching WISE G097.528+03.184 to parallax G097.53+03.18 based on WISE size
# Matching WISE G098.037+01.448 to parallax G098.03+01.44 based on WISE size
# Matching WISE G105.401+09.886 to parallax G105.41+09.87 based on WISE size
# Matching WISE G107.298+05.638 to parallax G107.29+05.63 based on WISE size
# Matching WISE G107.866+05.607 to parallax G108.18+05.51 based on WISE size
# Matching WISE G108.184+05.518 to parallax G108.18+05.51 based on WISE size
# Matching WISE G108.191+00.586 to parallax G108.20+00.58 based on WISE size
# Matching WISE G108.603+00.494 to parallax G108.59+00.49 based on WISE size
# Matching WISE G109.874+02.115 to parallax G109.87+02.11 based on WISE size
# Matching WISE G111.236-01.238 to parallax G111.23-01.23 based on WISE size
# Matching WISE G111.543+00.775 to parallax G111.54+00.77 based on WISE size
# Matching WISE G111.558+00.804 to parallax G111.54+00.77 based on WISE size
# Matching WISE G121.297+00.658 to parallax G121.29+00.65 based on WISE size
# Matching WISE G122.002-07.084 to parallax G122.01-07.08 based on WISE size
# Matching WISE G123.155-06.306 to parallax G123.06-06.30 based on WISE size
# Matching WISE G133.950+01.066 to parallax G133.94+01.06 based on WISE size
# Matching WISE G135.278+02.796 to parallax G135.27+02.79 based on WISE size
# Matching WISE G137.447+00.987 to parallax G136.84+01.16 based on WISE size
# Matching WISE G160.144+03.170 to parallax G160.14+03.15 based on WISE size
# Matching WISE G168.066+00.819 to parallax G168.06+00.82 based on WISE size
# Matching WISE G173.411+02.586 to parallax G173.48+02.44 based on WISE size
# Matching WISE G173.482+02.445 to parallax G173.48+02.44 based on WISE size
# Matching WISE G173.485+02.430 to parallax G173.48+02.44 based on separation (58.2 arcsec)
# Matching WISE G174.197-00.076 to parallax G174.20-00.07 based on WISE size
# Matching WISE G176.507+00.178 to parallax G176.51+00.20 based on WISE size
# Matching WISE G183.720-03.665 to parallax G183.72-03.66 based on WISE size
# Matching WISE G188.777+01.028 to parallax G188.79+01.03 based on WISE size
# Matching WISE G188.795+01.030 to parallax G188.79+01.03 based on WISE size
# Matching WISE G188.935+00.755 to parallax G188.94+00.88 based on WISE size
# Matching WISE G188.948+00.887 to parallax G188.94+00.88 based on WISE size
# Matching WISE G192.151-03.805 to parallax G192.16-03.81 based on WISE size
# Matching WISE G192.584-00.043 to parallax G192.60-00.04 based on separation (61.8 arcsec)
# Matching WISE G192.601-00.048 to parallax G192.60-00.04 based on WISE size
# Matching WISE G192.617-00.067 to parallax G192.60-00.04 based on separation (88.8 arcsec)
# Matching WISE G196.448-01.673 to parallax G196.45-01.67 based on WISE size
# Matching WISE G196.791-02.378 to parallax G196.45-01.67 based on WISE size
# Matching WISE G209.037-19.377 to parallax G209.00-19.38 based on WISE size
# Matching WISE G209.107-19.510 to parallax G209.00-19.38 based on WISE size
# Matching WISE G211.598+01.050 to parallax G211.59+01.05 based on WISE size
# Matching WISE G213.703-12.601 to parallax G213.70-12.59 based on WISE size
# Matching WISE G229.569+00.154 to parallax G229.57+00.15 based on WISE size
# Matching WISE G232.594+00.851 to parallax G232.62+00.99 based on WISE size
# Matching WISE G232.620+00.995 to parallax G232.62+00.99 based on WISE size
# Matching WISE G240.319+00.072 to parallax G240.31+00.07 based on WISE size
# Matching WISE G305.233+00.110 to parallax G305.20+00.01 based on WISE size
# Matching WISE G339.898-01.266 to parallax G339.88-01.25 based on WISE size
# Matching WISE G348.686-01.036 to parallax G348.70-01.04 based on separation (70.4 arcsec)
# Matching WISE G348.691-00.826 to parallax G348.70-01.04 based on WISE size
# Matching WISE G348.695-01.028 to parallax G348.70-01.04 based on separation (65.1 arcsec)
# Matching WISE G348.710-01.044 to parallax G348.70-01.04 based on WISE size
# Matching WISE G348.938-01.148 to parallax G348.70-01.04 based on WISE size
# Matching WISE G351.424+00.650 to parallax G351.44+00.65 based on WISE size
# Matching WISE G359.137+00.030 to parallax G359.13+00.03 based on WISE size
# Matching WISE G359.637-00.243 to parallax G359.61-00.24 based on separation (80.3 arcsec)
# Matching WISE G359.756-00.351 to parallax G359.61-00.24 based on WISE size
# Matching WISE G359.937-00.152 to parallax G359.93-00.14 based on WISE size
# Matching WISE G359.964-00.101 to parallax G359.93-00.14 based on WISE size
# Done!

# %% [markdown]
# # Compute Kinematic Distances for WISE-only Database

# %%
add_distances.main(wise_db_file, num_samples=100, batchsize=100, rotcurve="reid19_rotcurve", tablename="Distances_Reid2019")
# Out:
# Found 2126 unique Catalog sources with VLSR
#
# Resetting Distances_Reid2019 table...
# Done.
#
# Computing kinematic distances (group 0)...
# Done.
#
# Computing kinematic distances (group 1)...
# Done.
#
# Computing kinematic distances (group 2)...
# Done.
#
# Computing kinematic distances (group 3)...
# Done.
#
# Computing kinematic distances (group 4)...
# Process ForkPoolWorker-601:
# Process ForkPoolWorker-602:
# Process ForkPoolWorker-609:
# Process ForkPoolWorker-607:
# Process ForkPoolWorker-604:
# Process ForkPoolWorker-606:
# Process ForkPoolWorker-622:
# Process ForkPoolWorker-605:
# Process ForkPoolWorker-608:
# Process ForkPoolWorker-624:
# Process ForkPoolWorker-623:
# Process ForkPoolWorker-615:
# Process ForkPoolWorker-610:
# Process ForkPoolWorker-603:
# Process ForkPoolWorker-621:
# Process ForkPoolWorker-618:
# Traceback (most recent call last):
# Traceback (most recent call last):
# Traceback (most recent call last):
# Traceback (most recent call last):
# Traceback (most recent call last):
# Traceback (most recent call last):
# Traceback (most recent call last):
# Traceback (most recent call last):
# Traceback (most recent call last):
#   File "/home/twenger/miniforge3/envs/hii_db/lib/python3.11/site-packages/multiprocess/process.py", line 314, in _bootstrap
#     self.run()
# Traceback (most recent call last):
# Traceback (most recent call last):
# Traceback (most recent call last):
#   File "/home/twenger/miniforge3/envs/hii_db/lib/python3.11/site-packages/multiprocess/process.py", line 314, in _bootstrap
#     self.run()
#   File "/home/twenger/miniforge3/envs/hii_db/lib/python3.11/site-packages/multiprocess/process.py", line 314, in _bootstrap
#     self.run()
# Traceback (most recent call last):
#   File "/home/twenger/miniforge3/envs/hii_db/lib/python3.11/site-packages/multiprocess/process.py", line 314, in _bootstrap
#     self.run()
# Traceback (most recent call last):
#   File "/home/twenger/miniforge3/envs/hii_db/lib/python3.11/site-packages/multiprocess/process.py", line 314, in _bootstrap
#     self.run()
#   File "/home/twenger/miniforge3/envs/hii_db/lib/python3.11/site-packages/multiprocess/process.py", line 314, in _bootstrap
#     self.run()
# Traceback (most recent call last):
#   File "/home/twenger/miniforge3/envs/hii_db/lib/python3.11/site-packages/multiprocess/process.py", line 314, in _bootstrap
#     self.run()
#   File "/home/twenger/miniforge3/envs/hii_db/lib/python3.11/site-packages/multiprocess/process.py", line 314, in _bootstrap
#     self.run()
#   File "/home/twenger/miniforge3/envs/hii_db/lib/python3.11/site-packages/multiprocess/process.py", line 314, in _bootstrap
#     self.run()
#   File "/home/twenger/miniforge3/envs/hii_db/lib/python3.11/site-packages/multiprocess/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
# Traceback (most recent call last):
#   File "/home/twenger/miniforge3/envs/hii_db/lib/python3.11/site-packages/multiprocess/process.py", line 314, in _bootstrap
#     self.run()
#   File "/home/twenger/miniforge3/envs/hii_db/lib/python3.11/site-packages/multiprocess/process.py", line 314, in _bootstrap
#     self.run()
#   File "/home/twenger/miniforge3/envs/hii_db/lib/python3.11/site-packages/multiprocess/process.py", line 314, in _bootstrap
#     self.run()
#   File "/home/twenger/miniforge3/envs/hii_db/lib/python3.11/site-packages/multiprocess/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/home/twenger/miniforge3/envs/hii_db/lib/python3.11/site-packages/multiprocess/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/home/twenger/miniforge3/envs/hii_db/lib/python3.11/site-packages/multiprocess/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/home/twenger/miniforge3/envs/hii_db/lib/python3.11/site-packages/multiprocess/process.py", line 314, in _bootstrap
#     self.run()
#   File "/home/twenger/miniforge3/envs/hii_db/lib/python3.11/site-packages/multiprocess/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/home/twenger/miniforge3/envs/hii_db/lib/python3.11/site-packages/multiprocess/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
# Process ForkPoolWorker-620:
#   File "/home/twenger/miniforge3/envs/hii_db/lib/python3.11/site-packages/multiprocess/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/home/twenger/miniforge3/envs/hii_db/lib/python3.11/site-packages/multiprocess/process.py", line 314, in _bootstrap
#     self.run()
#   File "/home/twenger/miniforge3/envs/hii_db/lib/python3.11/site-packages/multiprocess/pool.py", line 114, in worker
#     task = get()
#            ^^^^^
#   File "/home/twenger/miniforge3/envs/hii_db/lib/python3.11/site-packages/multiprocess/process.py", line 314, in _bootstrap
#     self.run()
#   File "/home/twenger/miniforge3/envs/hii_db/lib/python3.11/site-packages/multiprocess/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/home/twenger/miniforge3/envs/hii_db/lib/python3.11/site-packages/multiprocess/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/home/twenger/miniforge3/envs/hii_db/lib/python3.11/site-packages/multiprocess/pool.py", line 114, in worker
#     task = get()
#            ^^^^^
#   File "/home/twenger/miniforge3/envs/hii_db/lib/python3.11/site-packages/multiprocess/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/home/twenger/miniforge3/envs/hii_db/lib/python3.11/site-packages/multiprocess/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/home/twenger/miniforge3/envs/hii_db/lib/python3.11/site-packages/multiprocess/pool.py", line 114, in worker
#     task = get()
#            ^^^^^
#   File "/home/twenger/miniforge3/envs/hii_db/lib/python3.11/site-packages/multiprocess/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/home/twenger/miniforge3/envs/hii_db/lib/python3.11/site-packages/multiprocess/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/home/twenger/miniforge3/envs/hii_db/lib/python3.11/site-packages/multiprocess/pool.py", line 114, in worker
#     task = get()
#            ^^^^^
#   File "/home/twenger/miniforge3/envs/hii_db/lib/python3.11/site-packages/multiprocess/pool.py", line 114, in worker
#     task = get()
#            ^^^^^
#   File "/home/twenger/miniforge3/envs/hii_db/lib/python3.11/site-packages/multiprocess/pool.py", line 114, in worker
#     task = get()
#            ^^^^^
#   File "/home/twenger/miniforge3/envs/hii_db/lib/python3.11/site-packages/multiprocess/pool.py", line 114, in worker
#     task = get()
#            ^^^^^
#   File "/home/twenger/miniforge3/envs/hii_db/lib/python3.11/site-packages/multiprocess/process.py", line 314, in _bootstrap
#     self.run()
#   File "/home/twenger/miniforge3/envs/hii_db/lib/python3.11/site-packages/multiprocess/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
# Traceback (most recent call last):
#   File "/home/twenger/miniforge3/envs/hii_db/lib/python3.11/site-packages/multiprocess/queues.py", line 367, in get
#     with self._rlock:
#   File "/home/twenger/miniforge3/envs/hii_db/lib/python3.11/site-packages/multiprocess/pool.py", line 114, in worker
#     task = get()
#            ^^^^^
#   File "/home/twenger/miniforge3/envs/hii_db/lib/python3.11/site-packages/multiprocess/pool.py", line 114, in worker
#     task = get()
#            ^^^^^
#   File "/home/twenger/miniforge3/envs/hii_db/lib/python3.11/site-packages/multiprocess/queues.py", line 367, in get
#     with self._rlock:
#   File "/home/twenger/miniforge3/envs/hii_db/lib/python3.11/site-packages/multiprocess/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/home/twenger/miniforge3/envs/hii_db/lib/python3.11/site-packages/multiprocess/pool.py", line 125, in worker
#     result = (True, func(*args, **kwds))
#                     ^^^^^^^^^^^^^^^^^^^
#   File "/home/twenger/miniforge3/envs/hii_db/lib/python3.11/site-packages/multiprocess/pool.py", line 114, in worker
#     task = get()
#            ^^^^^
#   File "/home/twenger/miniforge3/envs/hii_db/lib/python3.11/site-packages/multiprocess/pool.py", line 114, in worker
#     task = get()
#            ^^^^^
#   File "/home/twenger/miniforge3/envs/hii_db/lib/python3.11/site-packages/multiprocess/queues.py", line 367, in get
#     with self._rlock:
#   File "/home/twenger/miniforge3/envs/hii_db/lib/python3.11/site-packages/multiprocess/process.py", line 314, in _bootstrap
#     self.run()
#   File "/home/twenger/miniforge3/envs/hii_db/lib/python3.11/site-packages/multiprocess/queues.py", line 368, in get
#     res = self._reader.recv_bytes()
#           ^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/twenger/miniforge3/envs/hii_db/lib/python3.11/site-packages/multiprocess/queues.py", line 367, in get
#     with self._rlock:
#   File "/home/twenger/miniforge3/envs/hii_db/lib/python3.11/site-packages/multiprocess/queues.py", line 367, in get
#     with self._rlock:
#   File "/home/twenger/miniforge3/envs/hii_db/lib/python3.11/site-packages/multiprocess/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/home/twenger/miniforge3/envs/hii_db/lib/python3.11/site-packages/multiprocess/queues.py", line 367, in get
#     with self._rlock:
#   File "/home/twenger/miniforge3/envs/hii_db/lib/python3.11/site-packages/multiprocess/pool.py", line 114, in worker
#     task = get()
#            ^^^^^
#   File "/home/twenger/miniforge3/envs/hii_db/lib/python3.11/site-packages/multiprocess/queues.py", line 367, in get
#     with self._rlock:
#   File "/home/twenger/miniforge3/envs/hii_db/lib/python3.11/site-packages/multiprocess/synchronize.py", line 101, in __enter__
#     return self._semlock.__enter__()
#            ^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/twenger/miniforge3/envs/hii_db/lib/python3.11/site-packages/multiprocess/queues.py", line 367, in get
#     with self._rlock:
#   File "/home/twenger/miniforge3/envs/hii_db/lib/python3.11/site-packages/multiprocess/pool.py", line 125, in worker
#     result = (True, func(*args, **kwds))
#                     ^^^^^^^^^^^^^^^^^^^
#   File "/home/twenger/miniforge3/envs/hii_db/lib/python3.11/site-packages/multiprocess/synchronize.py", line 101, in __enter__
#     return self._semlock.__enter__()
#            ^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/twenger/miniforge3/envs/hii_db/lib/python3.11/site-packages/multiprocess/pool.py", line 125, in worker
#     result = (True, func(*args, **kwds))
#                     ^^^^^^^^^^^^^^^^^^^
#   File "/home/twenger/miniforge3/envs/hii_db/lib/python3.11/site-packages/multiprocess/queues.py", line 367, in get
#     with self._rlock:
#   File "/home/twenger/miniforge3/envs/hii_db/lib/python3.11/site-packages/multiprocess/queues.py", line 367, in get
#     with self._rlock:
#   File "/home/twenger/miniforge3/envs/hii_db/lib/python3.11/site-packages/multiprocess/synchronize.py", line 101, in __enter__
#     return self._semlock.__enter__()
#            ^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/twenger/miniforge3/envs/hii_db/lib/python3.11/site-packages/multiprocess/synchronize.py", line 101, in __enter__
#     return self._semlock.__enter__()
#            ^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/twenger/miniforge3/envs/hii_db/lib/python3.11/site-packages/multiprocess/pool.py", line 114, in worker
#     task = get()
#            ^^^^^
#   File "/home/twenger/miniforge3/envs/hii_db/lib/python3.11/site-packages/multiprocess/synchronize.py", line 101, in __enter__
#     return self._semlock.__enter__()
#            ^^^^^^^^^^^^^^^^^^^^^^^^^
# Process ForkPoolWorker-614:
#   File "/home/twenger/miniforge3/envs/hii_db/lib/python3.11/site-packages/multiprocess/pool.py", line 48, in mapstar
#     return list(map(*args))
#            ^^^^^^^^^^^^^^^^
#   File "/home/twenger/miniforge3/envs/hii_db/lib/python3.11/site-packages/multiprocess/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/home/twenger/miniforge3/envs/hii_db/lib/python3.11/site-packages/multiprocess/synchronize.py", line 101, in __enter__
#     return self._semlock.__enter__()
#            ^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/twenger/miniforge3/envs/hii_db/lib/python3.11/site-packages/multiprocess/synchronize.py", line 101, in __enter__
#     return self._semlock.__enter__()
#            ^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/twenger/miniforge3/envs/hii_db/lib/python3.11/site-packages/multiprocess/connection.py", line 219, in recv_bytes
#     buf = self._recv_bytes(maxlength)
#           ^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/twenger/miniforge3/envs/hii_db/lib/python3.11/site-packages/multiprocess/synchronize.py", line 101, in __enter__
#     return self._semlock.__enter__()
#            ^^^^^^^^^^^^^^^^^^^^^^^^^
# KeyboardInterrupt
#   File "/home/twenger/miniforge3/envs/hii_db/lib/python3.11/site-packages/multiprocess/queues.py", line 367, in get
#     with self._rlock:
#   File "/home/twenger/miniforge3/envs/hii_db/lib/python3.11/site-packages/multiprocess/pool.py", line 48, in mapstar
#     return list(map(*args))
#            ^^^^^^^^^^^^^^^^
# KeyboardInterrupt
#   File "/home/twenger/miniforge3/envs/hii_db/lib/python3.11/site-packages/multiprocess/pool.py", line 48, in mapstar
#     return list(map(*args))
#            ^^^^^^^^^^^^^^^^
# Process ForkPoolWorker-617:
# KeyboardInterrupt
# Traceback (most recent call last):
#   File "/home/twenger/miniforge3/envs/hii_db/lib/python3.11/site-packages/multiprocess/synchronize.py", line 101, in __enter__
#     return self._semlock.__enter__()
#            ^^^^^^^^^^^^^^^^^^^^^^^^^
# KeyboardInterrupt
# KeyboardInterrupt
#   File "/home/twenger/miniforge3/envs/hii_db/lib/python3.11/site-packages/multiprocess/queues.py", line 367, in get
#     with self._rlock:
#   File "/home/twenger/miniforge3/envs/hii_db/lib/python3.11/site-packages/multiprocess/synchronize.py", line 101, in __enter__
#     return self._semlock.__enter__()
#            ^^^^^^^^^^^^^^^^^^^^^^^^^
# Process ForkPoolWorker-613:
#   File "/home/twenger/miniforge3/envs/hii_db/lib/python3.11/site-packages/kd/rotcurve_kd.py", line 108, in work
#     [
# KeyboardInterrupt
#   File "/home/twenger/miniforge3/envs/hii_db/lib/python3.11/site-packages/multiprocess/pool.py", line 125, in worker
#     result = (True, func(*args, **kwds))
#                     ^^^^^^^^^^^^^^^^^^^
# KeyboardInterrupt
#   File "/home/twenger/miniforge3/envs/hii_db/lib/python3.11/site-packages/kd/rotcurve_kd.py", line 92, in work
#     grid_vlsrs = self.rotcurve_module.calc_vlsr(
#                  ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# KeyboardInterrupt
#   File "/home/twenger/miniforge3/envs/hii_db/lib/python3.11/site-packages/multiprocess/synchronize.py", line 101, in __enter__
#     return self._semlock.__enter__()
#            ^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/twenger/miniforge3/envs/hii_db/lib/python3.11/site-packages/multiprocess/connection.py", line 440, in _recv_bytes
#     return self._recv(size)
#            ^^^^^^^^^^^^^^^^
#   File "/home/twenger/miniforge3/envs/hii_db/lib/python3.11/site-packages/kd/rotcurve_kd.py", line 99, in work
#     [
#   File "/home/twenger/miniforge3/envs/hii_db/lib/python3.11/site-packages/multiprocess/synchronize.py", line 101, in __enter__
#     return self._semlock.__enter__()
#            ^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/twenger/miniforge3/envs/hii_db/lib/python3.11/site-packages/kd/rotcurve_kd.py", line 111, in <listcomp>
#     tan_idx != -1 and np.min(np.abs(vlsr[:tan_idx] - v)) < self.velo_tol
#                              ^^^^^^^^^^^^^^^^^^^^^^^^^^
# KeyboardInterrupt
#   File "/home/twenger/miniforge3/envs/hii_db/lib/python3.11/site-packages/multiprocess/pool.py", line 48, in mapstar
#     return list(map(*args))
#            ^^^^^^^^^^^^^^^^
# Traceback (most recent call last):
# Process ForkPoolWorker-619:
# KeyboardInterrupt
# KeyboardInterrupt
#   File "/home/twenger/miniforge3/envs/hii_db/lib/python3.11/site-packages/kd/reid19_rotcurve.py", line 232, in calc_vlsr
#     cos_az = np.cos(np.deg2rad(az))
#                     ^^^^^^^^^^^^^^
#   File "/home/twenger/miniforge3/envs/hii_db/lib/python3.11/site-packages/multiprocess/process.py", line 314, in _bootstrap
#     self.run()
# Traceback (most recent call last):
#   File "/home/twenger/miniforge3/envs/hii_db/lib/python3.11/site-packages/multiprocess/connection.py", line 405, in _recv
#     buf.write(chunk)
# KeyboardInterrupt
# KeyboardInterrupt
#   File "/home/twenger/miniforge3/envs/hii_db/lib/python3.11/site-packages/multiprocess/process.py", line 314, in _bootstrap
#     self.run()
#   File "/home/twenger/miniforge3/envs/hii_db/lib/python3.11/site-packages/kd/rotcurve_kd.py", line 92, in work
#     grid_vlsrs = self.rotcurve_module.calc_vlsr(
#                  ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# Traceback (most recent call last):
# KeyboardInterrupt
# KeyboardInterrupt
#   File "/home/twenger/miniforge3/envs/hii_db/lib/python3.11/site-packages/kd/rotcurve_kd.py", line 100, in <listcomp>
#     np.argmax(vlsr) if gl < 90.0 else np.argmin(vlsr) if gl > 270.0 else -1
#     ^^^^^^^^^^^^^^^
#   File "/home/twenger/miniforge3/envs/hii_db/lib/python3.11/site-packages/multiprocess/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/home/twenger/miniforge3/envs/hii_db/lib/python3.11/site-packages/multiprocess/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/home/twenger/miniforge3/envs/hii_db/lib/python3.11/site-packages/kd/reid19_rotcurve.py", line 223, in calc_vlsr
#     sin_glong = np.sin(np.deg2rad(glong))
#                 ^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/twenger/miniforge3/envs/hii_db/lib/python3.11/site-packages/multiprocess/pool.py", line 125, in worker
#     result = (True, func(*args, **kwds))
#                     ^^^^^^^^^^^^^^^^^^^
#   File "/home/twenger/miniforge3/envs/hii_db/lib/python3.11/site-packages/numpy/core/fromnumeric.py", line 1229, in argmax
#     return _wrapfunc(a, 'argmax', axis=axis, out=out, **kwds)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# KeyboardInterrupt
#   File "/home/twenger/miniforge3/envs/hii_db/lib/python3.11/site-packages/multiprocess/process.py", line 314, in _bootstrap
#     self.run()
#   File "/home/twenger/miniforge3/envs/hii_db/lib/python3.11/site-packages/multiprocess/pool.py", line 125, in worker
#     result = (True, func(*args, **kwds))
#                     ^^^^^^^^^^^^^^^^^^^
#   File "/home/twenger/miniforge3/envs/hii_db/lib/python3.11/site-packages/multiprocess/pool.py", line 48, in mapstar
#     return list(map(*args))
#            ^^^^^^^^^^^^^^^^
#   File "/home/twenger/miniforge3/envs/hii_db/lib/python3.11/site-packages/multiprocess/process.py", line 314, in _bootstrap
#     self.run()
#   File "/home/twenger/miniforge3/envs/hii_db/lib/python3.11/site-packages/multiprocess/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/home/twenger/miniforge3/envs/hii_db/lib/python3.11/site-packages/multiprocess/pool.py", line 48, in mapstar
#     return list(map(*args))
#            ^^^^^^^^^^^^^^^^
#   File "/home/twenger/miniforge3/envs/hii_db/lib/python3.11/site-packages/numpy/core/fromnumeric.py", line 59, in _wrapfunc
#     return bound(*args, **kwds)
#            ^^^^^^^^^^^^^^^^^^^^
#   File "/home/twenger/miniforge3/envs/hii_db/lib/python3.11/site-packages/kd/rotcurve_kd.py", line 92, in work
#     grid_vlsrs = self.rotcurve_module.calc_vlsr(
#                  ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/twenger/miniforge3/envs/hii_db/lib/python3.11/site-packages/multiprocess/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/home/twenger/miniforge3/envs/hii_db/lib/python3.11/site-packages/multiprocess/pool.py", line 125, in worker
#     result = (True, func(*args, **kwds))
#                     ^^^^^^^^^^^^^^^^^^^
#   File "/home/twenger/miniforge3/envs/hii_db/lib/python3.11/site-packages/kd/rotcurve_kd.py", line 92, in work
#     grid_vlsrs = self.rotcurve_module.calc_vlsr(
#                  ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/twenger/miniforge3/envs/hii_db/lib/python3.11/site-packages/multiprocess/pool.py", line 125, in worker
#     result = (True, func(*args, **kwds))
#                     ^^^^^^^^^^^^^^^^^^^
# KeyboardInterrupt
#   File "/home/twenger/miniforge3/envs/hii_db/lib/python3.11/site-packages/kd/reid19_rotcurve.py", line 229, in calc_vlsr
#     Rgal = kd_utils.calc_Rgal(glong, glat, dist, R0=R0)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/twenger/miniforge3/envs/hii_db/lib/python3.11/site-packages/kd/reid19_rotcurve.py", line 237, in calc_vlsr
#     theta = calc_theta(Rgal, a2=a2, a3=a3, R0=R0)
#             ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/twenger/miniforge3/envs/hii_db/lib/python3.11/site-packages/multiprocess/pool.py", line 48, in mapstar
#     return list(map(*args))
#            ^^^^^^^^^^^^^^^^
#   File "/home/twenger/miniforge3/envs/hii_db/lib/python3.11/site-packages/multiprocess/pool.py", line 48, in mapstar
#     return list(map(*args))
#            ^^^^^^^^^^^^^^^^
#   File "/home/twenger/miniforge3/envs/hii_db/lib/python3.11/site-packages/kd/kd_utils.py", line 77, in calc_Rgal
#     Rgal = np.sqrt(Rgal2)
#            ^^^^^^^^^^^^^^
#   File "/home/twenger/miniforge3/envs/hii_db/lib/python3.11/site-packages/kd/rotcurve_kd.py", line 92, in work
#     grid_vlsrs = self.rotcurve_module.calc_vlsr(
#                  ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/twenger/miniforge3/envs/hii_db/lib/python3.11/site-packages/kd/reid19_rotcurve.py", line 168, in calc_theta
#     theta = term1 / term2 * np.sqrt(term)
#                             ^^^^^^^^^^^^^
#   File "/home/twenger/miniforge3/envs/hii_db/lib/python3.11/site-packages/kd/rotcurve_kd.py", line 92, in work
#     grid_vlsrs = self.rotcurve_module.calc_vlsr(
#                  ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# KeyboardInterrupt
#   File "/home/twenger/miniforge3/envs/hii_db/lib/python3.11/site-packages/kd/reid19_rotcurve.py", line 231, in calc_vlsr
#     az = kd_utils.calc_az(glong, glat, dist, R0=R0)
#          ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# KeyboardInterrupt
#   File "/home/twenger/miniforge3/envs/hii_db/lib/python3.11/site-packages/kd/reid19_rotcurve.py", line 231, in calc_vlsr
#     az = kd_utils.calc_az(glong, glat, dist, R0=R0)
#          ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/twenger/miniforge3/envs/hii_db/lib/python3.11/site-packages/kd/kd_utils.py", line 110, in calc_az
#     Rgal = calc_Rgal(glong, glat, dist, R0=R0)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/twenger/miniforge3/envs/hii_db/lib/python3.11/site-packages/kd/kd_utils.py", line 121, in calc_az
#     az = np.rad2deg(np.arccos(cos_az))
#                     ^^^^^^^^^^^^^^^^^
# KeyboardInterrupt
#   File "/home/twenger/miniforge3/envs/hii_db/lib/python3.11/site-packages/kd/kd_utils.py", line 77, in calc_Rgal
#     Rgal = np.sqrt(Rgal2)
#            ^^^^^^^^^^^^^^
# KeyboardInterrupt
# Process ForkPoolWorker-612:
# Traceback (most recent call last):
#   File "/home/twenger/miniforge3/envs/hii_db/lib/python3.11/site-packages/multiprocess/process.py", line 314, in _bootstrap
#     self.run()
#   File "/home/twenger/miniforge3/envs/hii_db/lib/python3.11/site-packages/multiprocess/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/home/twenger/miniforge3/envs/hii_db/lib/python3.11/site-packages/multiprocess/pool.py", line 125, in worker
#     result = (True, func(*args, **kwds))
#                     ^^^^^^^^^^^^^^^^^^^
#   File "/home/twenger/miniforge3/envs/hii_db/lib/python3.11/site-packages/multiprocess/pool.py", line 48, in mapstar
#     return list(map(*args))
#            ^^^^^^^^^^^^^^^^
#   File "/home/twenger/miniforge3/envs/hii_db/lib/python3.11/site-packages/kd/rotcurve_kd.py", line 92, in work
#     grid_vlsrs = self.rotcurve_module.calc_vlsr(
#                  ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/twenger/miniforge3/envs/hii_db/lib/python3.11/site-packages/kd/reid19_rotcurve.py", line 237, in calc_vlsr
#     theta = calc_theta(Rgal, a2=a2, a3=a3, R0=R0)
#             ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/twenger/miniforge3/envs/hii_db/lib/python3.11/site-packages/kd/reid19_rotcurve.py", line 159, in calc_theta
#     term4 = 1.6 * np.exp(-0.4 * lam) * rho ** 2.0 / (rho ** 2.0 + 2.25 * lam ** 0.4)
#                   ^^^^^^^^^^^^^^^^^^
# KeyboardInterrupt
# Process ForkPoolWorker-616:
# Traceback (most recent call last):
# Process ForkPoolWorker-611:
#   File "/home/twenger/miniforge3/envs/hii_db/lib/python3.11/site-packages/multiprocess/process.py", line 314, in _bootstrap
#     self.run()
# Traceback (most recent call last):
#   File "/home/twenger/miniforge3/envs/hii_db/lib/python3.11/site-packages/multiprocess/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/home/twenger/miniforge3/envs/hii_db/lib/python3.11/site-packages/multiprocess/pool.py", line 125, in worker
#     result = (True, func(*args, **kwds))
#                     ^^^^^^^^^^^^^^^^^^^
#   File "/home/twenger/miniforge3/envs/hii_db/lib/python3.11/site-packages/multiprocess/process.py", line 314, in _bootstrap
#     self.run()
#   File "/home/twenger/miniforge3/envs/hii_db/lib/python3.11/site-packages/multiprocess/pool.py", line 48, in mapstar
#     return list(map(*args))
#            ^^^^^^^^^^^^^^^^
#   File "/home/twenger/miniforge3/envs/hii_db/lib/python3.11/site-packages/multiprocess/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/home/twenger/miniforge3/envs/hii_db/lib/python3.11/site-packages/kd/rotcurve_kd.py", line 92, in work
#     grid_vlsrs = self.rotcurve_module.calc_vlsr(
#                  ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/twenger/miniforge3/envs/hii_db/lib/python3.11/site-packages/multiprocess/pool.py", line 125, in worker
#     result = (True, func(*args, **kwds))
#                     ^^^^^^^^^^^^^^^^^^^
#   File "/home/twenger/miniforge3/envs/hii_db/lib/python3.11/site-packages/multiprocess/pool.py", line 48, in mapstar
#     return list(map(*args))
#            ^^^^^^^^^^^^^^^^
# KeyboardInterrupt
#   File "/home/twenger/miniforge3/envs/hii_db/lib/python3.11/site-packages/kd/rotcurve_kd.py", line 92, in work
#     grid_vlsrs = self.rotcurve_module.calc_vlsr(
#                  ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# KeyboardInterrupt
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# File ~/miniforge3/envs/hii_db/lib/python3.11/site-packages/kd/rotcurve_kd.py:288, in rotcurve_kd(glong, glat, velo, velo_err, velo_tol, rotcurve, dist_res, dist_min, dist_max, resample, size)
#     287 with mp.Pool() as pool:
# --> 288     results = pool.map(worker.work, range(size))
#     289 #
#     290 # Store results
#     291 #
#
# File ~/miniforge3/envs/hii_db/lib/python3.11/site-packages/multiprocess/pool.py:367, in Pool.map(self, func, iterable, chunksize)
#     363 '''
#     364 Apply `func` to each element in `iterable`, collecting the results
#     365 in a list that is returned.
#     366 '''
# --> 367 return self._map_async(func, iterable, mapstar, chunksize).get()
#
# File ~/miniforge3/envs/hii_db/lib/python3.11/site-packages/multiprocess/pool.py:768, in ApplyResult.get(self, timeout)
#     767 def get(self, timeout=None):
# --> 768     self.wait(timeout)
#     769     if not self.ready():
#
# File ~/miniforge3/envs/hii_db/lib/python3.11/site-packages/multiprocess/pool.py:765, in ApplyResult.wait(self, timeout)
#     764 def wait(self, timeout=None):
# --> 765     self._event.wait(timeout)
#
# File ~/miniforge3/envs/hii_db/lib/python3.11/threading.py:629, in Event.wait(self, timeout)
#     628 if not signaled:
# --> 629     signaled = self._cond.wait(timeout)
#     630 return signaled
#
# File ~/miniforge3/envs/hii_db/lib/python3.11/threading.py:327, in Condition.wait(self, timeout)
#     326 if timeout is None:
# --> 327     waiter.acquire()
#     328     gotit = True
#
# KeyboardInterrupt:
#
# During handling of the above exception, another exception occurred:
#
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[9], line 1
# ----> 1 add_distances.main(db_file, num_samples=100, batchsize=100, rotcurve="reid19_rotcurve", tablename="Distances_Reid2019")
#
# File ~/science/python/hii_db/hii_db/add_distances.py:277, in main(db, num_samples, batchsize, rotcurve, tablename)
#     274 print()
#     276 # Generate and add kinematic distances
# --> 277 compute_distances(
#     278     data,
#     279     db,
#     280     num_samples=num_samples,
#     281     batchsize=batchsize,
#     282     rotcurve=rotcurve,
#     283     tablename=tablename,
#     284 )
#
# File ~/science/python/hii_db/hii_db/add_distances.py:178, in compute_distances(data, db, num_samples, batchsize, rotcurve, tablename)
#     176 mydata = data[start:end]
#     177 print("Computing kinematic distances (group {0})...".format(i))
# --> 178 kdout = pdf_kd.pdf_kd(
#     179     mydata["glong"],
#     180     mydata["glat"],
#     181     mydata["vlsr"],
#     182     velo_err=mydata["e_vlsr"],
#     183     rotcurve=rotcurve,
#     184     num_samples=num_samples,
#     185 )
#     186 print("Done.")
#     187 print()
#
# File ~/miniforge3/envs/hii_db/lib/python3.11/site-packages/kd/pdf_kd.py:188, in pdf_kd(glong, glat, velo, velo_err, rotcurve, rotcurve_dist_res, rotcurve_dist_max, pdf_bins, num_samples, plot_pdf, plot_prefix)
#     155 results = {
#     156     "Rgal": np.zeros(glong.shape),
#     157     "Rgal_kde": np.empty(shape=glong.shape, dtype=object),
#    (...)    183     "vlsr_tangent_err_pos": np.zeros(glong.shape),
#     184 }
#     185 #
#     186 # Calculate rotcurve kinematic distance
#     187 #
# --> 188 kd_out = rotcurve_kd(
#     189     glong,
#     190     glat,
#     191     velo,
#     192     velo_err=velo_err,
#     193     velo_tol=0.1,
#     194     rotcurve=rotcurve,
#     195     dist_res=rotcurve_dist_res,
#     196     dist_min=0.01,
#     197     dist_max=rotcurve_dist_max,
#     198     resample=True,
#     199     size=num_samples,
#     200 )
#     201 #
#     202 # Set up multiprocessing for fitting KDEs
#     203 #
#     204 kdtypes = ["Rgal", "Rtan", "near", "far", "tangent", "vlsr_tangent"]
#
# File ~/miniforge3/envs/hii_db/lib/python3.11/site-packages/kd/rotcurve_kd.py:287, in rotcurve_kd(glong, glat, velo, velo_err, velo_tol, rotcurve, dist_res, dist_min, dist_max, resample, size)
#     271 #
#     272 # Initialize worker
#     273 #
#     274 worker = Worker(
#     275     glong,
#     276     glat,
#    (...)    285     size,
#     286 )
# --> 287 with mp.Pool() as pool:
#     288     results = pool.map(worker.work, range(size))
#     289 #
#     290 # Store results
#     291 #
#
# File ~/miniforge3/envs/hii_db/lib/python3.11/site-packages/multiprocess/pool.py:739, in Pool.__exit__(self, exc_type, exc_val, exc_tb)
#     738 def __exit__(self, exc_type, exc_val, exc_tb):
# --> 739     self.terminate()
#
# File ~/miniforge3/envs/hii_db/lib/python3.11/site-packages/multiprocess/pool.py:657, in Pool.terminate(self)
#     655 util.debug('terminating pool')
#     656 self._state = TERMINATE
# --> 657 self._terminate()
#
# File ~/miniforge3/envs/hii_db/lib/python3.11/site-packages/multiprocess/util.py:227, in Finalize.__call__(self, wr, _finalizer_registry, sub_debug, getpid)
#     224 else:
#     225     sub_debug('finalizer calling %s with args %s and kwargs %s',
#     226               self._callback, self._args, self._kwargs)
# --> 227     res = self._callback(*self._args, **self._kwargs)
#     228 self._weakref = self._callback = self._args = \
#     229                 self._kwargs = self._key = None
#     230 return res
#
# File ~/miniforge3/envs/hii_db/lib/python3.11/site-packages/multiprocess/pool.py:695, in Pool._terminate_pool(cls, taskqueue, inqueue, outqueue, pool, change_notifier, worker_handler, task_handler, result_handler, cache)
#     692 task_handler._state = TERMINATE
#     694 util.debug('helping task handler/workers to finish')
# --> 695 cls._help_stuff_finish(inqueue, task_handler, len(pool))
#     697 if (not result_handler.is_alive()) and (len(cache) != 0):
#     698     raise AssertionError(
#     699         "Cannot have cache with result_hander not alive")
#
# File ~/miniforge3/envs/hii_db/lib/python3.11/site-packages/multiprocess/pool.py:675, in Pool._help_stuff_finish(inqueue, task_handler, size)
#     671 @staticmethod
#     672 def _help_stuff_finish(inqueue, task_handler, size):
#     673     # task_handler may be blocked trying to put items on inqueue
#     674     util.debug('removing tasks from inqueue until task handler finished')
# --> 675     inqueue._rlock.acquire()
#     676     while task_handler.is_alive() and inqueue._reader.poll():
#     677         inqueue._reader.recv()
#
# KeyboardInterrupt:

# %% [markdown]
# # Build All-RRL Database

# %%
# Import packages
import os
from hii_db import generate
from hii_db import add_parallax
from hii_db import add_distances
from hii_db import balser_te_2015
from hii_db import wenger_te_2019
from hii_db import brown_shrds_pilot
from hii_db import wenger_shrds_2019
from hii_db import wenger_shrds_2021

import importlib
importlib.reload(generate)
importlib.reload(balser_te_2015)
importlib.reload(wenger_te_2019)
importlib.reload(brown_shrds_pilot)
importlib.reload(wenger_shrds_2019)
importlib.reload(wenger_shrds_2021)
# Out:
# <module 'hii_db.wenger_shrds_2021' from '/home/twenger/science/python/hii_db/hii_db/wenger_shrds_2021.py'>

# %%
generate.main(db_file, wise_csv_file, wise_only=False, data_dir=data_dir)
# Out:
# Resetting database...
# Done!
#
# Generating WISE Catalog table...
# 8589
# 8589
# Done!
#
# Generating Groups table...
# Group G000.510-00.051 different VLSR nan vs nan
# Group WB43 different VLSR nan vs nan
# Group WB43 different VLSR nan vs nan
# Done!
#
# Matching Catalog to Groups...
# Done!
#
# Adding WISE Detections...
# PROBLEM WITH G000.320-00.215 COMPONENTS
# [9.6]
# [0.5]
# [27.2]
# [0.7]
# [nan]
# [nan]
# ================================
# PROBLEM WITH G012.685+00.008 COMPONENTS
# [ 34.1 109. ]
# [0.7 0.9]
# [30.4  nan]
# [1.7 nan]
# [0.18105     nan]
# [0.03995     nan]
# ================================
# PROBLEM WITH G014.221-00.545 COMPONENTS
# [19.7 54.5]
# [0.8 1.7]
# [28.4  nan]
# [ 2. nan]
# [0.11475     nan]
# [0.0289    nan]
# ================================
# PROBLEM WITH G023.195-00.001 COMPONENTS
# [90.7 22.4]
# [0.7 1.7]
# [28.3  nan]
# [1.6 nan]
# [0.12155     nan]
# [0.02635     nan]
# ================================
# PROBLEM WITH G055.855-03.803 COMPONENTS
# [27.6]
# [0.2]
# [24.2]
# [0.3]
# [nan]
# [nan]
# ================================
# PROBLEM WITH G107.209-01.334 COMPONENTS
# [-36.]
# [0.4]
# [26.9]
# [0.7]
# [nan]
# [nan]
# ================================
# PROBLEM WITH G108.503+06.356 COMPONENTS
# [-10.3]
# [0.3]
# [23.9]
# [0.6]
# [nan]
# [nan]
# ================================
# PROBLEM WITH G114.605-00.801 COMPONENTS
# [-47.9]
# [0.8]
# [26.1]
# [1.5]
# [nan]
# [nan]
# ================================
# PROBLEM WITH G114.626+00.219 COMPONENTS
# [-32.8]
# [0.3]
# [29.]
# [0.6]
# [nan]
# [nan]
# ================================
# PROBLEM WITH G115.885-01.707 COMPONENTS
# [-43.8]
# [0.4]
# [26.9]
# [0.8]
# [nan]
# [nan]
# ================================
# PROBLEM WITH G118.621-01.329 COMPONENTS
# [-42.6]
# [0.5]
# [27.]
# [0.9]
# [nan]
# [nan]
# ================================
# PROBLEM WITH G134.970+00.699 COMPONENTS
# [-43.9]
# [0.3]
# [33.9]
# [0.4]
# [nan]
# [nan]
# ================================
# PROBLEM WITH G136.084+02.087 COMPONENTS
# [-44.7]
# [0.5]
# [31.3]
# [0.9]
# [nan]
# [nan]
# ================================
# PROBLEM WITH G136.119+02.118 COMPONENTS
# [-49.6]
# [0.3]
# [28.9]
# [0.6]
# [nan]
# [nan]
# ================================
# PROBLEM WITH G143.555-01.542 COMPONENTS
# [-36.7]
# [0.6]
# [35.9]
# [1.4]
# [nan]
# [nan]
# ================================
# PROBLEM WITH G147.984-00.335 COMPONENTS
# [-16.8]
# [0.3]
# [32.8]
# [0.6]
# [nan]
# [nan]
# ================================
# PROBLEM WITH G150.982-00.471 COMPONENTS
# [-23.9]
# [1.6]
# [33.8]
# [2.4]
# [nan]
# [nan]
# ================================
# PROBLEM WITH G152.687+02.889 COMPONENTS
# [-16.8]
# [0.6]
# [44.8]
# [1.3]
# [nan]
# [nan]
# ================================
# PROBLEM WITH G168.171+03.054 COMPONENTS
# [-23.1]
# [0.3]
# [35.1]
# [0.5]
# [nan]
# [nan]
# ================================
# PROBLEM WITH G168.750+00.873 COMPONENTS
# [-26.3]
# [0.4]
# [40.1]
# [0.6]
# [nan]
# [nan]
# ================================
# PROBLEM WITH G172.080-02.258 COMPONENTS
# [4.4]
# [0.1]
# [40.9]
# [0.2]
# [nan]
# [nan]
# ================================
# PROBLEM WITH G191.916+00.837 COMPONENTS
# [9.6]
# [2.]
# [39.1]
# [3.]
# [nan]
# [nan]
# ================================
# PROBLEM WITH G192.720+00.038 COMPONENTS
# [7.9]
# [1.1]
# [45.4]
# [1.8]
# [nan]
# [nan]
# ================================
# PROBLEM WITH G195.335-12.122 COMPONENTS
# [5.6]
# [0.4]
# [37.4]
# [0.6]
# [nan]
# [nan]
# ================================
# PROBLEM WITH G206.466-16.349 COMPONENTS
# [13.8]
# [0.2]
# [34.4]
# [0.3]
# [nan]
# [nan]
# ================================
# PROBLEM WITH G210.788-02.545 COMPONENTS
# [-21.   36.8]
# [0.4 0.3]
# [24.1 44.5]
# [0.6 0.6]
# [nan nan]
# [nan nan]
# ================================
# PROBLEM WITH G211.245-00.424 COMPONENTS
# [8.1]
# [0.4]
# [37.3]
# [0.6]
# [nan]
# [nan]
# ================================
# PROBLEM WITH G217.297-01.393 COMPONENTS
# [-21.   35.7]
# [1.5 1.4]
# [27.2 50.7]
# [2.1 2.4]
# [nan nan]
# [nan nan]
# ================================
# PROBLEM WITH G217.440+00.331 COMPONENTS
# [-18.5  23.6]
# [1.1 1.3]
# [20.2 36.3]
# [1.6 2.2]
# [nan nan]
# [nan nan]
# ================================
# PROBLEM WITH G217.629-00.178 COMPONENTS
# [16.6]
# [1.9]
# [61.2]
# [3.2]
# [nan]
# [nan]
# ================================
# PROBLEM WITH G218.131-00.397 COMPONENTS
# [16.3]
# [0.6]
# [47.1]
# [0.9]
# [nan]
# [nan]
# ================================
# PROBLEM WITH G218.808-04.558 COMPONENTS
# [-13.5  51.1]
# [1.2 0.8]
# [41.1 48. ]
# [1.8 1.4]
# [nan nan]
# [nan nan]
# ================================
# PROBLEM WITH G224.149-02.913 COMPONENTS
# [8.5]
# [0.7]
# [25.]
# [1.4]
# [nan]
# [nan]
# ================================
# PROBLEM WITH G224.405-02.740 COMPONENTS
# [13.9]
# [1.1]
# [25.4]
# [2.3]
# [nan]
# [nan]
# ================================
# PROBLEM WITH G231.142+01.503 COMPONENTS
# [45.7]
# [0.7]
# [16.6]
# [1.6]
# [nan]
# [nan]
# ================================
# PROBLEM WITH G232.594+00.851 COMPONENTS
# [-15.5  17.6]
# [1.2 0.3]
# [19.9 32.1]
# [1.7 0.5]
# [nan nan]
# [nan nan]
# ================================
# PROBLEM WITH G234.227-00.309 COMPONENTS
# [-10.3  42.8]
# [2.1 0.6]
# [32.8 35.5]
# [3.3 1. ]
# [nan nan]
# [nan nan]
# ================================
# PROBLEM WITH G352.587+02.104 COMPONENTS
# [0.6]
# [0.4]
# [28.5]
# [0.5]
# [nan]
# [nan]
# ================================
# PROBLEM WITH G355.924+01.634 COMPONENTS
# [6.6]
# [1.8]
# [22.7]
# [0.2]
# [nan]
# [nan]
# ================================
# PROBLEM WITH G358.464-01.897 COMPONENTS
# [-1.3]
# [0.6]
# [25.5]
# [0.3]
# [nan]
# [nan]
# ================================
# Done!
#
# Matching WISE Detections to WISE Catalog...
# Done!
#
# Adding Balser+2015 140 Foot data to Detections...
# Done!
#
# Matching 140 Foot Detections to WISE Catalog...
# Done!
#
# Adding Balser+2015 GBT data to Detections...
# Done!
#
# Matching GBT Detections to WISE Catalog...
# Found no Catalog match for GBT G032.960+00.276
# Min sep: G032.992+00.155 449.10 arcsec
# Found no Catalog match for GBT G032.960+00.276
# Min sep: G032.992+00.155 449.10 arcsec
# Done!
#
# Adding Wenger+2019 VLA data to Detections...
# Done!
#
# Matching VLA Detections to WISE Catalog...
# No match for G021.386-00.255
# No match for G021.386-00.255
# No match for G021.386-00.255
# No match for G021.386-00.255
# No match for G021.386-00.255
# No match for G021.386-00.255
# No match for G021.386-00.255
# No match for G021.386-00.255
# No match for G021.386-00.255
# No match for G021.386-00.255
# No match for G021.386-00.255
# No match for G021.386-00.255
# No match for G021.386-00.255
# No match for G021.386-00.255
# No match for G021.386-00.255
# No match for G021.386-00.255
# No match for G021.386-00.255
# No match for G021.386-00.255
# No match for G021.386-00.255
# No match for G021.386-00.255
# No match for G021.386-00.255
# No match for G021.386-00.255
# No match for G021.386-00.255
# No match for G021.386-00.255
# No match for G021.386-00.255
# No match for G021.386-00.255
# No match for G021.386-00.255
# No match for G021.386-00.255
# No match for G021.386-00.255
# No match for G021.386-00.255
# No match for G021.386-00.255
# No match for G021.386-00.255
# No match for G021.386-00.255
# No match for G021.386-00.255
# No match for G021.386-00.255
# No match for G021.386-00.255
# No match for G021.386-00.255
# No match for G021.386-00.255
# No match for G021.386-00.255
# No match for G021.386-00.255
# No match for G021.386-00.255
# No match for G021.386-00.255
# No match for G021.386-00.255
# No match for G021.386-00.255
# No match for G021.386-00.255
# No match for G021.386-00.255
# No match for G021.386-00.255
# No match for G021.386-00.255
# No match for G032.057+00.077
# No match for G032.057+00.077
# No match for G032.057+00.077
# No match for G032.057+00.077
# No match for G032.057+00.077
# No match for G032.057+00.077
# No match for G032.057+00.077
# No match for G032.057+00.077
# No match for G032.057+00.077
# No match for G032.057+00.077
# No match for G032.057+00.077
# No match for G032.057+00.077
# No match for G032.057+00.077
# No match for G032.057+00.077
# No match for G032.057+00.077
# No match for G032.057+00.077
# No match for G032.057+00.077
# No match for G032.057+00.077
# No match for G032.057+00.077
# No match for G032.057+00.077
# No match for G032.057+00.077
# No match for G032.057+00.077
# No match for G032.057+00.077
# No match for G032.057+00.077
# No match for G032.057+00.077
# No match for G032.057+00.077
# No match for G032.057+00.077
# No match for G032.057+00.077
# No match for G032.057+00.077
# No match for G032.057+00.077
# No match for G032.057+00.077
# No match for G032.057+00.077
# No match for G032.057+00.077
# No match for G032.057+00.077
# No match for G032.057+00.077
# No match for G032.057+00.077
# No match for G032.057+00.077
# No match for G032.057+00.077
# No match for G032.057+00.077
# No match for G032.057+00.077
# No match for G032.057+00.077
# No match for G032.057+00.077
# No match for G032.057+00.077
# No match for G032.057+00.077
# No match for G032.057+00.077
# No match for G032.057+00.077
# No match for G032.057+00.077
# No match for G032.057+00.077
# Done!
#
# Adding Brown+2017 SHRDS Pilot data to Detections...
# Done!
#
# Matching Brown+2017 SHRDS Pilot Detections to WISE Catalog...
# Done!
#
# Adding Wenger+2019 SHRDS data to Detections...
# Done!
#
# Matching Wenger+2019 SHRDS Detections to WISE Catalog...
# Could not find SHRDS Bright Catalog matches for:
# ['G259.359+00.820' 'G293.661-01.639' 'g294unknown' 'g298unknown'
#  'shrds063unknown' 'shrds075unknown' 'shrds253unknown' 'shrds412unknown'
#  'shrds450unknown' 'shrds465unknown' 'shrds690unknown' 'shrds771unknown'
#  'shrds836unknown' 'shrds864unknown']
# Done!
#
# Adding Wenger+2021 SHRDS Fields...
# Done!
#
# Adding Wenger+2021 SHRDS data to Detections and FieldsDetections...
# Done!
#
# Matching Wenger+2021 SHRDS Detections to WISE Catalog...
# Could not find SHRDS Full Catalog matches for:
# ['G021.386-00.255' 'G259.013-01.546' 'G259.268-02.611' 'G259.359+00.820'
#  'G261.638-02.095' 'G261.648-01.642' 'G293.661-01.639' 'G309.896+00.393'
#  'G333.508-00.138' 'G336.086-00.074' 'atca382u0' 'ch253u' 'ch79u'
#  'g290.012u' 'g294.656u' 'g300.972u' 'g308.033u' 'g345.864u' 'mos004u'
#  'mos016u' 'mos020u' 'mos021u' 'mos034u' 'mos036u' 'mos045u' 'mos064u'
#  'mos070u' 'mos099u' 'shrds034u' 'shrds075u1' 'shrds075u2' 'shrds1014u'
#  'shrds1024u' 'shrds1175gu' 'shrds1233u' 'shrds207u' 'shrds291u'
#  'shrds377u' 'shrds440u' 'shrds450' 'shrds450u' 'shrds465u' 'shrds621u'
#  'shrds764u' 'shrds773u' 'shrds775u' 'shrds864u' 'shrds885u' 'shrds900u']
# Done!
